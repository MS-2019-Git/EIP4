# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os 
#from random.eraser import get_random_eraser( this is showing Modulenotfounderror, thus adding the function in the code below)

# %%
# Training parameters
batch_size =128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10
random_erasing = False
pixel_level=False

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# %%
# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
print(model_type)


# Load the CIFAR10 data.
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# ResNet20v1
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 0.001 
    if epoch > 50:
        lr *= 0.1   
    if epoch > 40:
        lr *= 0.1
    elif epoch > 30:
        lr *= 0.1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2


    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_329 (Conv2D)             (None, 32, 32, 16)   448         input_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 32, 32, 16)   64          conv2d_329[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 32, 32, 16)   0           batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# conv2d_330 (Conv2D)             (None, 32, 32, 16)   2320        activation_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 32, 32, 16)   64          conv2d_330[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 32, 32, 16)   0           batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# conv2d_331 (Conv2D)             (None, 32, 32, 16)   2320        activation_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 32, 32, 16)   64          conv2d_331[0][0]
# __________________________________________________________________________________________________
# add_139 (Add)                   (None, 32, 32, 16)   0           activation_300[0][0]
#                                                                  batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 32, 32, 16)   0           add_139[0][0]
# __________________________________________________________________________________________________
# conv2d_332 (Conv2D)             (None, 32, 32, 16)   2320        activation_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 32, 32, 16)   64          conv2d_332[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 32, 32, 16)   0           batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# conv2d_333 (Conv2D)             (None, 32, 32, 16)   2320        activation_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 32, 32, 16)   64          conv2d_333[0][0]
# __________________________________________________________________________________________________
# add_140 (Add)                   (None, 32, 32, 16)   0           activation_302[0][0]
#                                                                  batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 32, 32, 16)   0           add_140[0][0]
# __________________________________________________________________________________________________
# conv2d_334 (Conv2D)             (None, 32, 32, 16)   2320        activation_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 32, 32, 16)   64          conv2d_334[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 32, 32, 16)   0           batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# conv2d_335 (Conv2D)             (None, 32, 32, 16)   2320        activation_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, 32, 32, 16)   64          conv2d_335[0][0]
# __________________________________________________________________________________________________
# add_141 (Add)                   (None, 32, 32, 16)   0           activation_304[0][0]
#                                                                  batch_normalization_306[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 32, 32, 16)   0           add_141[0][0]
# __________________________________________________________________________________________________
# conv2d_336 (Conv2D)             (None, 16, 16, 32)   4640        activation_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, 16, 16, 32)   128         conv2d_336[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 16, 16, 32)   0           batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# conv2d_337 (Conv2D)             (None, 16, 16, 32)   9248        activation_307[0][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 16, 16, 32)   544         activation_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 16, 16, 32)   128         conv2d_337[0][0]
# __________________________________________________________________________________________________
# add_142 (Add)                   (None, 16, 16, 32)   0           conv2d_338[0][0]
#                                                                  batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 16, 16, 32)   0           add_142[0][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 16, 16, 32)   9248        activation_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 16, 16, 32)   128         conv2d_339[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 16, 16, 32)   0           batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 16, 16, 32)   9248        activation_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 16, 16, 32)   128         conv2d_340[0][0]
# __________________________________________________________________________________________________
# add_143 (Add)                   (None, 16, 16, 32)   0           activation_308[0][0]
#                                                                  batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 16, 16, 32)   0           add_143[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 16, 16, 32)   9248        activation_310[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 16, 16, 32)   128         conv2d_341[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 16, 16, 32)   0           batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 16, 16, 32)   9248        activation_311[0][0]
# __________________________________________________________________________________________________
# batch_normalization_312 (BatchN (None, 16, 16, 32)   128         conv2d_342[0][0]
# __________________________________________________________________________________________________
# add_144 (Add)                   (None, 16, 16, 32)   0           activation_310[0][0]
#                                                                  batch_normalization_312[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 16, 16, 32)   0           add_144[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 8, 8, 64)     18496       activation_312[0][0]
# __________________________________________________________________________________________________
# batch_normalization_313 (BatchN (None, 8, 8, 64)     256         conv2d_343[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 8, 8, 64)     0           batch_normalization_313[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 8, 8, 64)     36928       activation_313[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 8, 8, 64)     2112        activation_312[0][0]
# __________________________________________________________________________________________________
# batch_normalization_314 (BatchN (None, 8, 8, 64)     256         conv2d_344[0][0]
# __________________________________________________________________________________________________
# add_145 (Add)                   (None, 8, 8, 64)     0           conv2d_345[0][0]
#                                                                  batch_normalization_314[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 8, 8, 64)     0           add_145[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 8, 8, 64)     36928       activation_314[0][0]
# __________________________________________________________________________________________________
# batch_normalization_315 (BatchN (None, 8, 8, 64)     256         conv2d_346[0][0]
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, 8, 8, 64)     0           batch_normalization_315[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 8, 8, 64)     36928       activation_315[0][0]
# __________________________________________________________________________________________________
# batch_normalization_316 (BatchN (None, 8, 8, 64)     256         conv2d_347[0][0]
# __________________________________________________________________________________________________
# add_146 (Add)                   (None, 8, 8, 64)     0           activation_314[0][0]
#                                                                  batch_normalization_316[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 8, 8, 64)     0           add_146[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 8, 8, 64)     36928       activation_316[0][0]
# __________________________________________________________________________________________________
# batch_normalization_317 (BatchN (None, 8, 8, 64)     256         conv2d_348[0][0]
# __________________________________________________________________________________________________
# activation_317 (Activation)     (None, 8, 8, 64)     0           batch_normalization_317[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 8, 8, 64)     36928       activation_317[0][0]
# __________________________________________________________________________________________________
# batch_normalization_318 (BatchN (None, 8, 8, 64)     256         conv2d_349[0][0]
# __________________________________________________________________________________________________
# add_147 (Add)                   (None, 8, 8, 64)     0           activation_316[0][0]
#                                                                  batch_normalization_318[0][0]
# __________________________________________________________________________________________________
# activation_318 (Activation)     (None, 8, 8, 64)     0           add_147[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 1, 1, 64)     0           activation_318[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 64)           0           average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 10)           650         flatten_15[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

#def scheduler(epoch, lr):  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

#lr_scheduler = LearningRateScheduler(scheduler, verbose=1)
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
#callbacks = [checkpoint, lr_scheduler]

# %%
# randome_eraser function
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input to implement CutOut
        #preprocessing_function=None,
        preprocessing_function=get_random_eraser(p=0.2,v_l=0, v_h=1, s_l=0.008, s_h=0.1,pixel_level=False),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
   # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                         validation_data=(x_test, y_test),workers=4,
                        epochs=epochs, verbose=1,callbacks=callbacks)
# Out:
# Epoch 1/50
# Learning rate:  0.001
# 391/391 [==============================] - 66s 169ms/step - loss: 1.7602 - acc: 0.4219 - val_loss: 1.9286 - val_acc: 0.4307
#
# Epoch 00001: val_acc improved from -inf to 0.43070, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 1.3250 - acc: 0.5776 - val_loss: 1.6734 - val_acc: 0.5004
#
# Epoch 00002: val_acc improved from 0.43070 to 0.50040, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 82ms/step - loss: 1.1267 - acc: 0.6541 - val_loss: 1.1401 - val_acc: 0.6558
#
# Epoch 00003: val_acc improved from 0.50040 to 0.65580, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 1.0005 - acc: 0.6991 - val_loss: 1.1919 - val_acc: 0.6445
#
# Epoch 00004: val_acc did not improve from 0.65580
# Epoch 5/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.9227 - acc: 0.7281 - val_loss: 1.3194 - val_acc: 0.6167
#
# Epoch 00005: val_acc did not improve from 0.65580
# Epoch 6/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.8611 - acc: 0.7486 - val_loss: 1.2763 - val_acc: 0.6550
#
# Epoch 00006: val_acc did not improve from 0.65580
# Epoch 7/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.8145 - acc: 0.7666 - val_loss: 0.8781 - val_acc: 0.7430
#
# Epoch 00007: val_acc improved from 0.65580 to 0.74300, saving model to /content/saved_models/cifar10_ResNet20v1_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.7718 - acc: 0.7837 - val_loss: 1.1593 - val_acc: 0.6643
#
# Epoch 00008: val_acc did not improve from 0.74300
# Epoch 9/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.7389 - acc: 0.7933 - val_loss: 0.9913 - val_acc: 0.7297
#
# Epoch 00009: val_acc did not improve from 0.74300
# Epoch 10/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.7222 - acc: 0.7992 - val_loss: 1.0519 - val_acc: 0.7078
#
# Epoch 00010: val_acc did not improve from 0.74300
# Epoch 11/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.6915 - acc: 0.8086 - val_loss: 1.1922 - val_acc: 0.6927
#
# Epoch 00011: val_acc did not improve from 0.74300
# Epoch 12/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.6701 - acc: 0.8171 - val_loss: 0.8120 - val_acc: 0.7716
#
# Epoch 00012: val_acc improved from 0.74300 to 0.77160, saving model to /content/saved_models/cifar10_ResNet20v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 82ms/step - loss: 0.6536 - acc: 0.8237 - val_loss: 0.8572 - val_acc: 0.7544
#
# Epoch 00013: val_acc did not improve from 0.77160
# Epoch 14/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6359 - acc: 0.8297 - val_loss: 0.8474 - val_acc: 0.7674
#
# Epoch 00014: val_acc did not improve from 0.77160
# Epoch 15/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6228 - acc: 0.8341 - val_loss: 0.8665 - val_acc: 0.7641
#
# Epoch 00015: val_acc did not improve from 0.77160
# Epoch 16/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6071 - acc: 0.8392 - val_loss: 1.2927 - val_acc: 0.6563
#
# Epoch 00016: val_acc did not improve from 0.77160
# Epoch 17/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5942 - acc: 0.8454 - val_loss: 0.9939 - val_acc: 0.7370
#
# Epoch 00017: val_acc did not improve from 0.77160
# Epoch 18/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5835 - acc: 0.8484 - val_loss: 0.9076 - val_acc: 0.7516
#
# Epoch 00018: val_acc did not improve from 0.77160
# Epoch 19/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5690 - acc: 0.8531 - val_loss: 0.6450 - val_acc: 0.8279
#
# Epoch 00019: val_acc improved from 0.77160 to 0.82790, saving model to /content/saved_models/cifar10_ResNet20v1_model.019.h5
# Epoch 20/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5639 - acc: 0.8556 - val_loss: 0.7149 - val_acc: 0.8129
#
# Epoch 00020: val_acc did not improve from 0.82790
# Epoch 21/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5574 - acc: 0.8580 - val_loss: 0.7849 - val_acc: 0.7840
#
# Epoch 00021: val_acc did not improve from 0.82790
# Epoch 22/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5404 - acc: 0.8634 - val_loss: 0.7706 - val_acc: 0.7965
#
# Epoch 00022: val_acc did not improve from 0.82790
# Epoch 23/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 82ms/step - loss: 0.5375 - acc: 0.8648 - val_loss: 1.0428 - val_acc: 0.7275
#
# Epoch 00023: val_acc did not improve from 0.82790
# Epoch 24/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5295 - acc: 0.8680 - val_loss: 0.8723 - val_acc: 0.7850
#
# Epoch 00024: val_acc did not improve from 0.82790
# Epoch 25/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5213 - acc: 0.8713 - val_loss: 0.8391 - val_acc: 0.7791
#
# Epoch 00025: val_acc did not improve from 0.82790
# Epoch 26/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5135 - acc: 0.8739 - val_loss: 0.8546 - val_acc: 0.7652
#
# Epoch 00026: val_acc did not improve from 0.82790
# Epoch 27/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5050 - acc: 0.8765 - val_loss: 0.7483 - val_acc: 0.8105
#
# Epoch 00027: val_acc did not improve from 0.82790
# Epoch 28/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5029 - acc: 0.8771 - val_loss: 1.0083 - val_acc: 0.7543
#
# Epoch 00028: val_acc did not improve from 0.82790
# Epoch 29/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4972 - acc: 0.8798 - val_loss: 0.8368 - val_acc: 0.7978
#
# Epoch 00029: val_acc did not improve from 0.82790
# Epoch 30/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.4844 - acc: 0.8854 - val_loss: 0.7475 - val_acc: 0.8133
#
# Epoch 00030: val_acc did not improve from 0.82790
# Epoch 31/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4840 - acc: 0.8843 - val_loss: 0.6335 - val_acc: 0.8416
#
# Epoch 00031: val_acc improved from 0.82790 to 0.84160, saving model to /content/saved_models/cifar10_ResNet20v1_model.031.h5
# Epoch 32/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4141 - acc: 0.9088 - val_loss: 0.4963 - val_acc: 0.8838
#
# Epoch 00032: val_acc improved from 0.84160 to 0.88380, saving model to /content/saved_models/cifar10_ResNet20v1_model.032.h5
# Epoch 33/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3890 - acc: 0.9183 - val_loss: 0.4863 - val_acc: 0.8852
#
# Epoch 00033: val_acc improved from 0.88380 to 0.88520, saving model to /content/saved_models/cifar10_ResNet20v1_model.033.h5
# Epoch 34/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.3791 - acc: 0.9209 - val_loss: 0.5010 - val_acc: 0.8848
#
# Epoch 00034: val_acc did not improve from 0.88520
# Epoch 35/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.3691 - acc: 0.9249 - val_loss: 0.4855 - val_acc: 0.8883
#
# Epoch 00035: val_acc improved from 0.88520 to 0.88830, saving model to /content/saved_models/cifar10_ResNet20v1_model.035.h5
# Epoch 36/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3601 - acc: 0.9272 - val_loss: 0.4870 - val_acc: 0.8858
#
# Epoch 00036: val_acc did not improve from 0.88830
# Epoch 37/50
# Learning rate:  0.0001
# 391/391 [==============================] - 30s 76ms/step - loss: 0.3581 - acc: 0.9263 - val_loss: 0.5001 - val_acc: 0.8834
#
# Epoch 00037: val_acc did not improve from 0.88830
# Epoch 38/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.3528 - acc: 0.9285 - val_loss: 0.4898 - val_acc: 0.8860
#
# Epoch 00038: val_acc did not improve from 0.88830
# Epoch 39/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3482 - acc: 0.9293 - val_loss: 0.4763 - val_acc: 0.8890
#
# Epoch 00039: val_acc improved from 0.88830 to 0.88900, saving model to /content/saved_models/cifar10_ResNet20v1_model.039.h5
# Epoch 40/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.3443 - acc: 0.9297 - val_loss: 0.4850 - val_acc: 0.8884
#
# Epoch 00040: val_acc did not improve from 0.88900
# Epoch 41/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3368 - acc: 0.9323 - val_loss: 0.4795 - val_acc: 0.8875
#
# Epoch 00041: val_acc did not improve from 0.88900
# Epoch 42/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 82ms/step - loss: 0.3365 - acc: 0.9317 - val_loss: 0.4897 - val_acc: 0.8862
#
# Epoch 00042: val_acc did not improve from 0.88900
# Epoch 43/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3322 - acc: 0.9332 - val_loss: 0.4907 - val_acc: 0.8848
#
# Epoch 00043: val_acc did not improve from 0.88900
# Epoch 44/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3289 - acc: 0.9341 - val_loss: 0.5059 - val_acc: 0.8804
#
# Epoch 00044: val_acc did not improve from 0.88900
# Epoch 45/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3251 - acc: 0.9364 - val_loss: 0.4764 - val_acc: 0.8862
#
# Epoch 00045: val_acc did not improve from 0.88900
# Epoch 46/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.3233 - acc: 0.9355 - val_loss: 0.4877 - val_acc: 0.8839
#
# Epoch 00046: val_acc did not improve from 0.88900
# Epoch 47/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3220 - acc: 0.9358 - val_loss: 0.5018 - val_acc: 0.8818
#
# Epoch 00047: val_acc did not improve from 0.88900
# Epoch 48/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3155 - acc: 0.9370 - val_loss: 0.4914 - val_acc: 0.8829
#
# Epoch 00048: val_acc did not improve from 0.88900
# Epoch 49/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.3145 - acc: 0.9386 - val_loss: 0.4737 - val_acc: 0.8907
#
# Epoch 00049: val_acc improved from 0.88900 to 0.89070, saving model to /content/saved_models/cifar10_ResNet20v1_model.049.h5
# Epoch 50/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.3143 - acc: 0.9380 - val_loss: 0.4843 - val_acc: 0.8851
#
# Epoch 00050: val_acc did not improve from 0.89070

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 3s 303us/step
# Test loss: 0.484324564409256
# Test accuracy: 0.8851
